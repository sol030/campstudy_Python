# %% [markdown]
# > ✏️ 이 문제들은 **정답이 하나만 있는 문제**가 아닙니다.
# > **목표 출력이 나오면 정답입니다.**
# > 직접 실행하면서 결과를 꼭 확인하세요.

# %% [markdown]
# # 1단원. `print()`, `sep`, `end`

# %% [markdown]
# __문제 1-1) `sep` 기본 연습__
# sep을 사용해서 아래의 목표출력과 같이 출력하도록 코드를 완성하세요.
#
# 📌 목표 출력
#
# ```
# a-b-c
# ```
#
# 💡 힌트
# * `sep`는 **값 사이에 들어갈 문자**입니다.
# * 문자열은 따옴표로 감싸야 합니다.

# %%
# 1-1번. 아래 코드를 완성하세요.
print("a", "b", "c", sep= )
# Out:
#   Cell In[2], line 2
#     print("a", "b", "c", sep= )
#                          ^
# SyntaxError: expected argument value expression

# %% [markdown]
# __문제 1-2 :  날짜 출력하기__
# 아래의 목표출력과 같이 출력하도록 코드를 완성하세요.
#
# 📌 목표 출력
#
# ```
# 2026/1/4
# ```
#
# 💡 힌트
# * 숫자도 `print()`로 바로 출력할 수 있습니다.
# * `/`도 문자열입니다.

# %%
# 1-2번. 아래 코드를 완성하세요.
print(2026, 1, 4, sep= )

# %% [markdown]
# ### 1-3) 줄바꿈 없이 출력하기 (`end`)
#
# ### 📌 목표 출력
#
# ```
# Hello World
# ```
#
# 💡 힌트
#
# * `print()`는 원래 **출력 후 줄바꿈**을 합니다.
# * `end`를 바꾸면 줄바꿈을 막을 수 있습니다.

# %%
# 1-3번. 아래 코드를 완성하세요.
print("Hello", end= )
print("World")
# Out:
#   Cell In[1], line 2
#     print("Hello", end= )
#                    ^
# SyntaxError: expected argument value expression

# %% [markdown]
# ### 1-4) `sep`와 `end` 같이 쓰기
#
# 📌 목표 출력
#
# ```
# A|B|C...DONE
# ```
#
# 💡 힌트
#
# * `|`와 `...` 중 무엇이 `sep`이고 무엇이 `end`일지 생각해 보세요.

# %%
# 1-4번. 아래 코드를 완성하세요.
print("A", "B", "C", sep= , end= )
print("DONE")

# %% [markdown]
# ### 1-5) 여러 줄 출력을 한 줄로 바꾸기
#
# 📌 목표 출력
#
# ```
# 1 2 3 4 5
# ```
#
# 💡 힌트
#
# * `end=" "` 를 어디에 써야 할까요?
# * 마지막 숫자는 줄바꿈해도 됩니다.

# %%
# 1-5번. 아래 코드를 **수정**하세요
print("1")
print("2")
print("3")
print("4")
print("5")

# %% [markdown]
# ### 1-6번
#
# `print()`를 2번만 써서 다음처럼 출력해 보세요.
#
# 📌 목표 출력
# ```
# 사과 / 바나나 / 포도
# 끝
# ```
#
# 💡 힌트
#
# * 한 줄에 여러 값을 출력할 수 있습니다.
# * `/` 앞뒤에 공백이 있습니다.

# %%
# 1-6번. 아래 코드를 완성하세요.
print()
print()

# %% [markdown]
# ## 1-7번: 문자열과 숫자의 차이 느껴보기
# 문제 : 아래 이유들을 적어 보세요
#
# * `"1"` 과 `1`의 차이는 무엇인가요?
# * 결과가 왜 다르게 나왔나요?

# %%
### ✍️ 직접 실행해 보세요
print("1")
print(1)

print("1" + "1")
print(1 + 1)
# Out:
# 1
# 1
# 11
# 2

# %% [markdown]
# 1-7번 답안지. 아래에 설명을 적어보세요.

# %% [markdown]
# # 2단원. f-string으로 변수랑 문자열이랑 함께 출력하기
#
# >✏️ 이 단원에서는 문자열 안에 변수 값을 예쁘게 넣는 방법을 연습합니다.
#
# > 출력 결과가 목표 출력과 같으면 정답입니다.

# %% [markdown]
# ### 2-1번
#
#  `name="적토마"`, `age=15`일 때:
# `적토마의 나이는 15살입니다.` 를 f-string으로 출력해 보세요.
#
# 📌 목표 출력
# ```
# 적토마의 나이는 15살입니다.
# ```
#
#
#
# 💡 힌트
# - 문자열 앞에 f를 붙여야 합니다.
# - {} 안에 변수 이름을 넣습니다.

# %%
# 2-1번. 아래 코드를 완성하세요.
name = "적토마"
age = 15
print()

# %% [markdown]
# ### 2-2번 : 숫자에 콤마 찍기 (f-string)
# 큰 숫자를 사람이 읽기 쉽게 **콤마(,)**를 찍어 출력해 보세요.
# `money=9876543`일 때: `총액: 9,876,543원` 을 f-string으로 출력해 보세요.
#
# 📌 목표 출력
#
# ```
# 총액: 9,876,543원
# ```
#
# 💡 힌트
#
# * f-string 안에서 숫자 서식을 사용할 수 있습니다.
# * 콤마는 `:` 뒤에 옵션을 씁니다.

# %%
# 2-2번. 아래 코드를 완성하세요.
money = 9876543
print()

# %% [markdown]
# ### 2-3) 소수점 자리수 맞추기
#
# 평균값을 **소수 둘째 자리까지만** 보이도록 출력해 보세요.
#
# 📌 목표 출력
#
# ```
# 평균: 3.14
# ```
#
# 💡 힌트
# * 소수점 자릿수는 `f` 옵션으로 조절합니다.
# * 반올림이 자동으로 적용됩니다.

# %%
# 2-3번. 아래 코드를 완성하세요.
avg = 3.14159
print()

# %% [markdown]
# ### 2-4) f-string이 안 되는 이유
#
# ### 📌 문제 지문
#
# 아래 코드를 실행했더니 `{name}`이 그대로 출력되었습니다.
# ```
# python
# name = "적토마"
# print("{name}님 환영합니다")
# ```
#
# **왜 이런 결과가 나왔는지 이유를 생각해 보세요.**
#
# 📝 적어 보세요
#
# * `{name}`이 변수 값으로 바뀌지 않은 이유는 무엇인가요?
# * 무엇이 빠졌나요?

# %%
# 2-4번. 아래 코드를 ""실행""해보세요
name = "적토마"
print("{name}님 환영합니다")

# %% [markdown]
# 2-4번. 이유를 해당 markdown 블록에 적어주세요.

# %% [markdown]
# ### 2-5) 계산 결과를 f-string으로 출력하기
#
# 두 수 `a`, `b`의 나눗셈 결과를
# **소수 둘째 자리까지** 출력해 보세요.
#
# 📌 주어진 값
#
# ```python
# a = 12
# b = 5
# ```
#
# 📌 목표 출력
#
# ```
# 12 / 5 = 2.40
# ```
#
# 💡 힌트
#
# * `{}` 안에서 계산식을 바로 쓸 수 있습니다.
# * 소수점 자릿수 옵션을 함께 사용하세요.

# %%
# 2-5번. 아래 코드를 완성하세요.
print( )

# %% [markdown]
# ### 2-6) 콤마 + 소수 둘째 자리 함께 쓰기
# 가격을 출력할 때
#
# * **천 단위 콤마**
# * **소수 둘째 자리**
#
# 를 모두 적용해 보세요.
#
# 📌 주어진 값
#
# ```python
# price = 12345.6
# ```
#
# 📌 목표 출력
#
# ```
# 가격: 12,345.60원
# ```
#
# 💡 힌트
#
# * 콤마와 소수점 옵션을 **함께** 사용할 수 있습니다.
# * 옵션 순서에 주의하세요.

# %%
# 2-6번. 아래 코드를 완성하세요.
price = 12345.6
print( )

# %% [markdown]
# ### 문제 2-7) `format()`으로 다시 도전
#
# 이번에는 **f-string을 사용하지 않고**,
# `format()`을 사용해서 **문제 2-2와 같은 출력**을 만들어 보세요.
#
# 📌 주어진 값
# ```python
# money = 9876543
# ```
#
# 📌 목표 출력
# ```
# 총액: 9,876,543원
# ```
#
# 💡 힌트
#
# * `"문자열 {}".format(값)` 형태를 사용합니다.
# * 콤마 옵션도 적용할 수 있습니다.

# %%
# 2-7번. 아래 코드를 완성하세요.
print( )

# %% [markdown]
# # 3단원: input + 형변환 + 예외처리 (총 9문제)
# >이 단원에서는
#   문자열 입력(input) → 숫자로 변환(type casting) →
#   오류가 발생했을 때 프로그램이 멈추지 않도록 처리하는 연습을 합니다.
#   ⚠️ 모든 문제는 직접 실행해서 확인하세요.

# %% [markdown]
# ### 문제 3-1) 정수 입력 → 2배 출력
#
# 문제 설명
# 사용자가 정수 하나를 입력하면 그 수의 2배 값을 출력하세요.
#
# 입력 예시:
# ```
# 7
# ```
#
# 목표 출력:
# ```
# 14
# ```
#
# 힌트
# - input()의 결과는 문자열입니다.
# - 계산을 하려면 숫자로 바꿔야 합니다.

# %%
# 3-1번, 아래 코드를 완성하세요.
num = input()
print()

# %% [markdown]
# ### 문제 3-2) 실수 입력 → 1 더하기
#
# 문제 설명
# 사용자가 실수 하나를 입력하면 그 값에 1을 더한 결과를 출력하세요.
#
# 입력 예시:
# ```
# 2.5
# ```
#
# 목표 출력:
# ```
# 3.5
# ```
#
# 힌트
# - int()가 아닌 다른 형변환이 필요합니다.

# %%
num = input()
float_num = float(num)
print(float_num + 1)
# Out:
# 5.5

# %% [markdown]
# ### 문제 3-3) 문자열 덧셈 vs 숫자 덧셈
#
# 문제 설명
# 아래 코드를 실행하고 결과를 직접 확인해 보세요.
#
# 입력 예시:
# ```
# 1
# 2
# ```
#
# 확인할 것
# - 출력 결과는 무엇인가요?
# - 왜 3이 아니라 "12"가 나왔나요?
#
# 힌트
# - 문자열의 + 와 숫자의 + 는 다릅니다.

# %%
# 3-3번
a = input()
b = input()
print(a + b)
# Out:
# 12

# %% [markdown]
# ### 문제 3-4) 공백으로 구분된 두 정수 처리
#
# 문제 설명
# 공백으로 구분된 정수 2개를 입력받아 아래를 모두 출력하세요.
#
# - 합
# - 차
# - 곱
#
# 입력 예시:
# ```
# 8 3
# ```
#
# 목표 출력:
# ```
# 합: 11
# 차: 5
# 곱: 24
# ```
#
# 힌트
# - 문자열을 공백 기준으로 나눌 수 있습니다.
# - 나눈 결과는 아직 문자열입니다.

# %%
# 3-4번, 아래 코드를 완성하세요.
data = input()

# 합 / 차 / 곱 출력

# %% [markdown]
# ### 문제 3-5) 입력 형식이 이상할 때 처리하기
#
# 문제 설명
# 문제 3-4를 확장합니다.
# 입력 형식이 이상하면 계산 대신 아래 문장을 출력하세요.
#
# 목표 출력:
# ```
# 형식이 잘못되었습니다
# ```
#
# 힌트
# - try / except를 사용합니다.
# - 숫자 변환 과정에서 오류가 발생할 수 있습니다.

# %%
# 3-5번, 아래 코드를 완성하세요.
data = input()

# try / except 사용

# %% [markdown]
# ### 문제 3-6) 쉼표로 구분된 입력 처리
#
# 문제 설명
# x,y 형태로 정수 2개를 입력받아 곱을 출력하세요.
#
# 입력 예시:
# ```
# 4,5
# ```
#
# 목표 출력:
# ```
# 20
# ```
#
# 힌트
# - 쉼표 기준으로 문자열을 나눕니다.
# - 공백이 함께 들어올 수도 있습니다.

# %%
# 3-6번, 아래 코드를 완성하세요.
data = input()
print()

# %% [markdown]
# ### 문제 3-7) 콤마가 포함된 숫자 처리하기
#
# 문제 설명
# 1,000 같은 입력도 받을 수 있도록 콤마를 제거한 뒤
# 정수로 바꿔 2배를 출력하세요.
#
# 입력 예시:
# ```
# 1,000
# ```
#
# 목표 출력:
# ```
# 2000
# ```
#
# 힌트
# - 문자열에서 특정 문자를 제거할 수 있습니다.

# %%
# 3-7번, 아래 코드를 완성하세요.
num = input()
print()

# %% [markdown]
# ### 문제 3-8) int("3.14")는 왜 실패할까요?
#
# 문제 설명
# 아래 코드를 직접 실행해 보고 오류를 확인하세요.
#
# 확인할 것
# - 어떤 오류가 발생했나요?
# - 대신 어떤 형변환을 사용해야 하나요?
#
# 힌트
# - 정수와 실수는 다른 타입입니다.

# %%
# 아래 코드를 실행해보고, 오류를 확인하세요.
print(int("3.14"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 아래 코드를 실행해보고, 오류를 확인하세요.
# ----> 2 print(int("3.14"))
#
# ValueError: invalid literal for int() with base 10: '3.14'

# %% [markdown]
# 3-8번. 왜 그런지 아래에 설명하세요.

# %% [markdown]
# #

# %% [markdown]
# # 연습문제 04) split + map + replace
#
# >이 단원에서는
#   문자열 분리(split) → 여러 값 형변환(map) → 입력 검증
#   을 집중적으로 연습합니다.
#
#   ⚠️ 모든 문제는 직접 실행해 보며 결과를 확인하세요.

# %% [markdown]
# ### 문제 4-1) 공백으로 구분된 정수 3개의 합
#
# 문제 설명
# 공백으로 구분된 정수 3개를 입력받아 합을 출력하세요.
#
# 입력 예시:
# ```
# 3 5 7
# ```
#
# 목표 출력:
# ```
# 15
# ```
#
# 힌트
# - split() 기본 기준은 공백입니다.
# - 나눈 값들은 모두 정수로 변환해야 합니다.

# %%
# 4-1번
data = input()
print()

# %% [markdown]
# ### 문제 4-2) 쉼표로 구분된 정수 3개의 평균
#
# 문제 설명
# 쉼표로 구분된 정수 3개를 입력받아 평균을 소수 둘째 자리까지 출력하세요.
#
# 입력 예시:
# ```
# 10,20,30
# ```
#
# 목표 출력:
# ```
# 20.00
# ```
#
# 힌트
# - 쉼표(,) 기준으로 split 합니다.
# - 평균은 실수 계산입니다.

# %%
# 4-2번
data = input()
print()

# %% [markdown]
# ### 문제 4-3) #로 구분된 정수 4개의 최댓값
#
# 문제 설명
# #로 구분된 정수 4개 중 최댓값을 출력하세요.
#
# 입력 예시:
# ```
# 3#9#1#7
# ```
#
# 목표 출력:
# ```
# 9
# ```
#
# 힌트
# - #도 문자열입니다.
# - 숫자로 변환 후 비교합니다.

# %%
# 4-3번
data = input()
print()

# %% [markdown]
# ### 문제 4-4) 왜 실패할까요? (헷갈림)
#
# 문제 설명
# 아래 코드는 입력이 `10,20`일 때 실패합니다.
# 이유를 직접 확인하고 해결 방법을 생각해 보세요.
#
# 실험 코드:
# ```python
# a, b = map(int, input().split())
# ```
#
# 입력 예시:
# ```
# 10,20
# ```
#
# 힌트
# - split()은 기본적으로 공백 기준입니다.

# %%
# 4-4번
a, b = map(int, input().split())
print(a, b)

# %% [markdown]
# ### 문제 4-5) 쉼표 + 공백이 섞인 입력 처리
#
# 문제 설명
# 쉼표 뒤에 공백이 있어도 정상적으로 평균을 출력하세요.
#
# 입력 예시:
# ```
# 10, 20, 30
# ```
#
# 목표 출력:
# ```
# 20
# ```
#
# 힌트
# - 입력 문자열을 먼저 정리할 수 있습니다.

# %%
# 4-5번
data = input()
text = data.replace(' ', '')
numbers = list(map(int, text.split(',')))
print(sum(numbers) / len(numbers))
# Out:
# 20.0

# %% [markdown]
# ### 문제 4-6) 정수가 아닐 때 예외 처리
#
# 문제 설명
# 입력값 중 하나라도 정수가 아니면
# 아래 문장을 출력하세요.
#
# 목표 출력:
# ```
# 정수만 입력하세요
# ```
#
# 힌트
# - 형변환 과정에서 오류가 발생합니다.
# - try / except를 사용하세요.

# %%
# 4-6번
data = input()

# try / except 사용

# %% [markdown]
# ### 문제 4-7) 입력 개수 검증하기
#
# 문제 설명
# 정수 2개만 입력해야 합니다.
# 개수가 다르면 아래 문장을 출력하세요.
#
# 목표 출력:
# ```
# 정수 2개를 입력하세요
# ```
#
# 힌트
# - split() 결과의 길이를 확인합니다.

# %%
# 4-7번
data = input()
print()

# %% [markdown]
# ### 문제 4-8) 콤마가 섞인 숫자 처리하기
#
# 문제 설명
# 천 단위 콤마가 섞인 숫자도 처리하여 합을 출력하세요.
#
# 입력 예시:
# ```
# 1,000 2,000
# ```
#
# 목표 출력:
# ```
# 3000
# ```
#
# 힌트
# - 숫자 안의 콤마를 제거한 뒤 변환합니다.

# %%
# 4-8번
data = input()
print()

# %% [markdown]
# ### 문제 4-9) 점수 평균 + f-string 출력
#
# 문제 설명
# 점수 3개의 평균을 구해 f-string으로 소수 둘째 자리까지 출력하세요.
#
# 입력 예시:
# ```
# 80 90 100
# ```
#
# 목표 출력:
# ```
# 평균: 90.00
# ```
#
# 힌트
# - 계산과 출력 형식을 분리해서 생각하세요.

# %%
# 4-9번
data = input()
print()

# %% [markdown]
# ### 문제 4-10) 모든 구분자 처리하기 (도전, 선택풀기)
#
# 문제 설명
# 입력이 공백 / 쉼표 / # 중 어떤 것으로 구분되어도
# 두 정수의 합이 출력되도록 만드세요.
#
# 입력 예시:
# ```
# 10 20
# 10,20
# 10#20
# ```
#
# 목표 출력:
# ```
# 30
# ```
#
# 힌트
# - replace는 여러번 실행되어도 괜찮습니다.

# %%
# 4-10번
data = input()
print()
