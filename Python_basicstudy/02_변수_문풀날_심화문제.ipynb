# %% [markdown]
# # 변수_심화문제
#
# 1) `x = 10` 다음에 `x = x + 1`은 어떤 의미인가요?
# 2) `x = "10"`일 때 `x + 1`은 왜 에러일까요? 해결 방법은?
# 3) `a, b = 3, 7` 후 `a, b = b, a`는 어떤 결과인가요?
# 4) `x=y=z=0`을 쓰는 이유는 무엇인가요?
# 5) `10 / 2`가 `5.0`이 되는 이유는 무엇인가요?
# 6) `Score`와 `score`가 다른 변수인 이유는?
# 7) `total score = 100`이 왜 안 되나요?
# 8) 전역 변수 “읽기”와 “수정”의 차이를 한 줄로 정리하세요.
# 9) `"10" + "20"`과 `int("10") + int("20")`의 차이를 설명하세요.
# 10) (도전) 정수 2개를 입력받아 합/차/곱/나눗셈을 모두 출력하세요.

# %%
# 종합 문제 1
# TODO

# %%
# 종합 문제 2
# TODO

# %%
# 종합 문제 3
# TODO

# %%
# 종합 문제 4
# TODO

# %%
# 종합 문제 5
# TODO

# %%
# 종합 문제 6
# TODO

# %%
# 종합 문제 7
# TODO

# %%
# 종합 문제 8
# TODO

# %%
# 종합 문제 9
# TODO

# %%
# 종합 문제 10
# TODO
