# %% [markdown]
# ### 🧩 연습문제: `print`, `sep`, `end` (총 8문제)
#
# **문제 1)** 아래 출력이 나오도록 `sep`를 사용해 보세요.
# 목표 출력: `a-b-c`
#
# **문제 2)** 아래 출력이 나오도록 `sep`를 사용해 보세요.
# 목표 출력: `2026/01/04` (01, 04처럼 0 포함은 아직 어렵다면 `2026/1/4`도 괜찮습니다)
#
# **문제 3)** 아래 출력이 한 줄로 이어지게 `end`를 사용해 보세요.
# 목표 출력: `Hello World`
#
# **문제 4)** 아래 출력이 나오도록 `sep`와 `end`를 같이 써 보세요.
# 목표 출력: `A|B|C...DONE`
#
# **문제 5)** 다음 코드를 수정해서 `1 2 3 4 5`가 한 줄로 나오게 해 보세요.
#
# **문제 6)** `print()`를 2번만 써서 다음처럼 출력해 보세요.
# 목표 출력:
# ```
# 사과 / 바나나 / 포도
# 끝
# ```
#
# **문제 7)** 문자열 `"1"`과 숫자 `1`을 각각 출력해 보고, 차이를 말해 보세요(직접 실행).
#
# **문제 8)** 아래와 같은 “진행바 느낌”을 만들어 보세요.
# 목표 출력(예시): `0...1...2...3...4...끝!`

# %%
# 문제 1
# TODO
print("a", "b", "c", sep = '-')
# Out:
# a-b-c

# %%
# 문제 1
# TODO
print(2026, 1, 4, sep = '/0')
# Out:
# 2026/01/04

# %%
print("Hello", end = " ")
print("World")
# Out:
# Hello World

# %%
print("A", "B", "C", sep = "|" , end = "...")
print("DONE")
# Out:
# A|B|C...DONE

# %%
print("1", end = " ")
print("2", end = " ")
print("3", end = " ")
print("4", end = " ")
print("5", end = " ")
# Out:
# 1 2 3 4 5

# %%
print(f"사과 / 바나나 / 포도")
print("끝")
# Out:
# 사과 / 바나나 / 포도
# 끝

# %%
print("1")
print(1)

print("1" + "1")
print(1 + 1)
# Out:
# 1
# 1
# 11
# 2

# %%
for i in range(5):
    print(f"{i}...", end="")
print("끝!")
# Out:
# 0...1...2...3...4...끝!

# %% [markdown]
# ### 🧩 연습문제: f-string / format (총 7문제)
#
# **문제 1)** `name="적토마"`, `age=15`일 때:
# `적토마의 나이는 15살입니다.` 를 f-string으로 출력해 보세요.
#
# **문제 2)** `money=9876543`일 때:
# `총액: 9,876,543원` 을 f-string으로 출력해 보세요.
#
# **문제 3)** `avg=3.14159`일 때:
# `평균: 3.14` 를 f-string으로 출력해 보세요.
#
# **문제 4)** (헷갈림) 아래 코드에서 왜 `{name}`이 그대로 나오나요?
# 힌트: `f`를 확인하세요.
#
# **문제 5)** `a=12`, `b=5`일 때:
# `12 / 5 = 2.40` 을 f-string으로 출력해 보세요(소수 둘째 자리).
#
# **문제 6)** `price=12345.6`일 때:
# `가격: 12,345.60원` 을 f-string으로 출력해 보세요(콤마 + 소수 둘째 자리).
#
# **문제 7)** `format()`으로도 문제 2를 똑같이 출력해 보세요.

# %%
name = "적토마"
age = 15
print(f"{name}의 나이는 {age}입니다.")
#적토마의 나이는 15입니다.﻿​

# %%
# 문제 2
# TODO
money = 9876543
print(f"총액: {money:,}원")
# Out:
# 총액: 9,876,543원

# %%
# 문제 3
# TODO
avg = 3.14159
print(f"평균: {avg:.2f}")
# Out:
# 평균: 3.14

# %%
# 2-4번. 아래 코드를 ""실행""해보세요
name = "적토마"
print(f"{name} 님 환영합니다")
# Out:
# 적토마 님 환영합니다

# %%
# 문제 5
# TODO
a, b = 12, 5
print(f"{a} / {b} = {a/b:.2f}")
# Out:
# 12 / 5 = 2.40

# %%
# 문제 6
# TODO
price = 12345.6
print(f"가격: {price:,.2f}원")
# Out:
# 가격: 12,345.60

# %%
# 문제 7
# TODO (format 사용)
money = 9876543
print("총액: {:,}".format(money))
# Out:
# 총액: 9,876,543

# %% [markdown]
# ### 🧩 연습문제: input + 형변환 + 예외처리 (총 9문제)
#
# **문제 1)** 사용자가 정수를 입력하면 2배를 출력하세요.
# **문제 2)** 사용자가 실수를 입력하면 1을 더해서 출력하세요.
# **문제 3)** (헷갈림) 사용자 입력 두 개를 받아 `a+b`를 출력할 때, 왜 `"12"`가 나오기도 하나요? 직접 실험해 보세요.
# **문제 4)** 공백으로 구분된 정수 2개를 입력받아 `합/차/곱`을 출력하세요.
# **문제 5)** 위 문제에서 입력이 이상하면 “형식이 잘못되었습니다”를 출력하세요. (`try/except`)
# **문제 6)** `x,y` 형태(쉼표 구분)로 정수 2개를 입력받아 곱을 출력하세요.
# **문제 7)** `1,000` 같은 입력도 받을 수 있게 콤마를 제거한 뒤 정수로 바꿔보세요.
# **문제 8)** (헷갈림) `int("3.14")`는 왜 실패하나요? 대신 어떤 변환을 써야 하나요? 직접 코드로 확인하세요.
# **문제 9)** 0으로 나눌 때 프로그램이 멈추지 않게 처리하세요.

# %%
num = input()
int_num = int(num)
print(int_num*2)
# Out:
# 12

# %%
# 문제 2
# TODO
num = input()
float_num = float(num)
print(float_num + 1)
# Out:
# 5.5

# %%
# 문제 3
# TODO
a = input()
b = input()
a_num = int(a)
b_num = int(b)
print(a_num + b_num)
# Out:
# 3

# %%
# 문제 4
# TODO
a = input()
b = input()
a_num = int(a)
b_num = int(b)
print(f"합 : {a_num + b_num}")
print(f"차 : {a_num - b_num}")
print(f"곱 : {a_num * b_num}")
# Out:
# 합 : 10
# 차 : 6
# 곱 : 16

# %%
# 문제 5
# TODO
a = input()
b = input()
try:
    a_num = int(a)
    b_num = int(b)
except ValueError:
    print("숫자 변환 과정에서 오류가 발생했습니다!")
else:
    print(f"합 : {a_num + b_num}")
    print(f"차 : {a_num - b_num}")
    print(f"곱 : {a_num * b_num}")
# Out:
# 숫자 변환 과정에서 오류가 발생했습니다!

# %%
# 문제 6
# TODO
a = input()
print(a.split(','))
# Out:
# ['3', '2']

# %%
a = input()
parts = a.split(',')
a, b = map(int, parts)
print(a * b)
# Out:
# 25

# %%
a = input()
a_num = int(a.replace(",", ""))
print(f"{a_num*2:,}")
# Out:
# 8,000

# %%
# 문제 8
# TODO
#print(int("3.14"))
print(float("3.14"))
# Out:
# 3.14

# %%
# 문제 9
# TODO
a = input()
b = input()
try:
    a_num = int(a)
    b_num = int(b)
    print(a_num/b_num)
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다!")
# Out:
# 0으로 나눌 수 없습니다!

# %% [markdown]
# ### 🧩 연습문제: split + map (총 10문제)
#
#
# **문제 1)** 공백으로 구분된 정수 3개를 입력받아 합을 출력하세요.
# **문제 2)** 쉼표로 구분된 정수 3개를 입력받아 평균을 출력하세요(소수 둘째 자리).
# **문제 3)** `#`로 구분된 정수 4개를 입력받아 최댓값을 출력하세요.
# **문제 4)** (헷갈림) `a, b = map(int, input().split())`에서 입력을 `10,20`으로 하면 왜 실패할까요? 해결하세요.
# **문제 5)** `10, 20, 30`처럼 쉼표 뒤 공백이 있어도 잘 동작하도록 처리하세요.
# **문제 6)** 입력이 정수가 아닐 경우 “정수만 입력하세요”라고 출력하세요.
# **문제 7)** 입력이 2개가 아닐 경우 “정수 2개를 입력하세요”라고 출력하세요.
# **문제 8)** 입력이 `1,000 2,000`처럼 콤마가 섞여 있어도 합이 나오게 해 보세요.
# **문제 9)** 점수 3개를 입력받아 평균을 구하고, f-string으로 소수 둘째 자리까지 출력하세요.
# **문제 10)** (도전) 입력 형식이 공백/쉼표/# 중 어떤 것이든 들어올 수 있습니다.
# 가능한 경우를 모두 지원해 보세요(힌트: 먼저 어떤 구분자가 있는지 검사).

# %%
# split/map 문제 1
# TODO
num = input("공백으로 구분해 정수 3개를 입력하세요.")
parts = num.split(' ')
a, b, c = map(int, parts)
print(a + b + c)
# Out:
# 14

# %%
# split/map 문제 2
# TODO
num = input("쉼표로 구분해 정수 3개를 입력하세요.")
parts = num.split(',')
numbers = [float(p) for p in parts]
num_avg = sum(numbers) / len(numbers)
print(f"평균: {num_avg:.2f}")
# Out:
# 평균: 16.00

# %%
# split/map 문제 3
# TODO
a, b = map(int, input().split('#'))    #입력받고, #으로 나눠서 정수로 바꾼 다음 각각 a, b에 넣기
print(max(a, b))
# Out:
# 4

# %%
a, b = map(int, input().split(','))
print(a, b)
# Out:
# 10 20

# %%
# split/map 문제 5
# TODO
data = input()
text = data.replace(' ', '')		#1 2 묶어서 data = input().replace(' ', '')로 해도 되는데 보기 편하라고 이렇게 나눔
numbers = list(map(int, text.split(',')))	#, 를 기준으로 분리하고, 정수로 변환해서 리스트에 넣음
print(sum(numbers) / len(numbers))	#평균
# Out:
# 5.333333333333333

# %%
# split/map 문제 6
# TODO
try:        #try는 가장 작은 범위로 감싸는 게 베스트
    data = list(map(int, input().split()))
except ValueError:
    print("정수만 입력하세요.")
else:
    print(data)
# Out:
# 정수만 입력하세요.

# %%
# split/map 문제 7
# TODO
data = list(map(int, input().split()))

if len(data) != 2:
    print("정수 2개를 입력하세요")
else:
    print(data)
# Out:
# 정수 2개를 입력하세요

# %%
# split/map 문제 8
# TODO
a, b = map(int, input().replace(",", "").split())
print(a + b)
# Out:
# 3000

# %%
# split/map 문제 9
# TODO
num = list(map(int, input().split()))   #map은 한번만 순회 가능한 객체라 list 써야함
print(sum(num) / len(num))
# Out:
# 90.0

# %%
# split/map 문제 10
# TODO
a, b = map(int, input().replace(",", " ").replace("#", " ").split())
print(a+b)
# Out:
# 4
