# %% [markdown]
# ### 필수 1번: `if`는 거짓이면 else로 가는가?
# 아래 코드의 출력 결과는 무엇인가요?
# 먼저 손으로 답을 예측해보고, 실제로 실행해본 결과와 비교해보세요.
# 그리고 왜 그런지 설명해보세요.
#
# __힌트__
# * `0`은 False
# * `if`가 False여도 **프로그램은 멈추지 않는다**
# * `else`가 없으면 그냥 다음 줄로 내려간다

# %% [raw]
# # 필수 1번 코드
# x = 0
#
# if x:
#     print("A")
# print("B")

# %% [markdown]
# __필수예제 1번 답안지__
#
# B

# %% [markdown]
# ---
# ### 필수예제 2번: `elif`는 모두 검사될까?
# 아래 코드의 출력 결과는 무엇인가요?
# 먼저 손으로 답을 예측해보고, 실제로 실행해본 결과와 비교해보세요.
# 그리고 왜 그런지 설명해보세요.
#
# __힌트__
# * `elif`는 **앞 조건이 False일 때만** 검사
# * True가 하나라도 나오면 **즉시 종료**

# %% [raw]
# # 필수예제 2번
# score = 95
#
# if score >= 90:
#     print("A")
# elif score >= 80:
#     print("B")
# elif score >= 70:
#     print("C")

# %% [markdown]
# __필수예제 2번 답안지__
#
# A

# %% [markdown]
# ---
# ### 필수예제 3번 : 조건 순서가 바뀌면 결과가 바뀐다
# 이 코드는 의도대로 동작하는가?
# 먼저 손으로 답을 예측해보고, 실제로 실행해본 결과와 비교해보세요.
# 그리고 왜 그런지 설명해보세요.
#
# __힌트__
# * 더 **넓은 조건을 먼저 쓰면**, 뒤 조건은 영원히 실행되지 않음
# * 조건은 **구체적인 것 → 일반적인 것** 순서로 작성해야 함

# %% [raw]
# # 필수예제 3번 코드
# age = 10
#
# if age >= 0:
#     print("사람입니다.")
# elif age >= 18:
#     print("성인입니다.")

# %% [markdown]
# __필수예제 3번 답안지__
#
# 실행 X 첫줄에서 끝남

# %% [markdown]
# ---
# ### 필수예제 4번:  `and` / `or` 혼동
# 이 조건은 어떤 값의 x에서 False가 될까?
# 먼저 손으로 답을 예측해보고, 실제로 실행해본 결과와 비교해보세요.
# 그리고 왜 그런지 설명해보세요.
#
# __힌트__
# * `or`은 조건을 **넓힌다**
# * 이 조건은 **거의 항상 True**
# * 가끔은 사실상 쓸모없는 조건문이 있을수도 있다.

# %% [raw]
# # 필수예제 4번 코드
# x = 5
#
# if x > 0 or x < 10:
#     print("OK")

# %% [markdown]
# __필수예제 4번 답안지__
#
# or이라 항상 TRUE가 됨. and로 범위를 좁혀줘야 한다

# %% [markdown]
# ---
# ### 필수예제 5번 : `not`의 대상은 어디까지인가?
#
# 아래 코드를 실행하면 어떤 결과가 나올까요?
# 먼저 손으로 답을 예측해보고, 실제로 실행해본 결과와 비교해보세요.
# 그리고 왜 그런지 설명해보세요.
#
# __힌트__
# * `not`은 **x가 아니라 (x > 3)의 결과**를 뒤집는다
# * `x > 3` → True
# * `not True` → False

# %% [markdown]
# # 필수예제 5번 코드
# x = 5
#
# if not x > 3:
#     print("A")
# else:
#     print("B")

# %% [markdown]
# __필수예제 5번 답안지__
#
# B.
# (5 > 3)은 True지만 not이 붙어 False가 된다. 따라서 else 문이 실행됨

# %% [markdown]
# ---
# ### 필수예제 6번 : 삼항 연산자
#
# 아래 코드를 실행하면 어떤 결과가 나올까요?
# 먼저 손으로 답을 예측해보고, 실제로 실행해본 결과와 비교해보세요.
# 그리고 왜 그런지 설명해보세요.
#
# __힌트__
# * 조건식에 **정수 자체를 쓰면 truthy / falsy로 판단**
# * `0`은 False
# * 가독성과 의도가 매우 나쁜 삼항연산자는 안쓰느니만 못하다

# %% [raw]
# x = 0
#
# result = "양수" if x else "0 또는 음수"
# print(result)

# %% [markdown]
# __필수예제 6번 답안지__
#
# 0 또는 음수 / 조건을 제대로 써야함

# %% [markdown]
# ---
#
# __필수예제 7번__
#
# 사용자로부터 정수를 입력받은 뒤, 해당 정수가 다음 조건 중 하나에 해당하는지 판별하는 프로그램을 작성하세요.
#
# - 3의 배수이면서 동시에 7의 배수인 경우: "3과 7의 공배수입니다." 출력
# - 3의 배수이지만 7의 배수는 아닌 경우: "3의 배수입니다." 출력
# - 7의 배수이지만 3의 배수는 아닌 경우: "7의 배수입니다." 출력
# - 위의 어떤 조건도 만족하지 않으면: "3과 7의 배수가 아닙니다." 출력

# %%
'''테스트 입력값

입력: 21
21은 3의 배수이면서 7의 배수 → "3과 7의 공배수입니다."

입력: 9
9는 3의 배수지만 7의 배수 아님 → "3의 배수입니다."

입력: 14
14는 7의 배수지만 3의 배수 아님 → "7의 배수입니다."

입력: 10
3의 배수도, 7의 배수도 아님 → "3과 7의 배수가 아닙니다."'''
# Out:
# '테스트 입력값\n\n입력: 21\n21은 3의 배수이면서 7의 배수 → "3과 7의 공배수입니다."\n\n입력: 9\n9는 3의 배수지만 7의 배수 아님 → "3의 배수입니다."\n\n입력: 14\n14는 7의 배수지만 3의 배수 아님 → "7의 배수입니다."\n\n입력: 10\n3의 배수도, 7의 배수도 아님 → "3과 7의 배수가 아닙니다."'

# %%
# 필수예제 7번을 아래 코드에 작성하세요.

data = int(input("입력:"))

if data % 3 == 0 and data % 7 == 0:
    print("3과 7의 공배수입니다.")
elif data % 3 == 0 and data % 7 != 0:
    print("3의 배수입니다.")
elif data % 3 != 0 and data % 7 == 0:
    print("7의 배수입니다.")
else:
    print ("3과 7의 배수가 아닙니다.")
# Out:
# 3의 배수입니다.

# %% [markdown]
# ---
# ### 필수예제 8번
# 사용자로부터 문자열을 입력받아, 해당 문자열이 모두 알파벳으로만 이루어져 있으며(공백 없음), 길이가 8 이상인 경우 "사용 가능한 비밀번호입니다."를 출력하고, 그렇지 않으면 "사용 불가능한 비밀번호입니다."를 출력하세요.
#
#
# 특이 사항(아래 함수들을 모른다면 google 검색 or chatgpt 검색!!! ex. 파이썬 isalpha() 검색 후 정리된 블로그 글을 보고, 해당 문제에 적용!)
# 1. isaplha() 사용(해당 문자열이 모두 알파벳으로만 이뤄져 있는지 확인하는 함수)
# 2. len() 사용(문자열 길이 측정하는 함수)

# %% [markdown]
# '''테스트 입력값
#
# 입력: abcdefgh
# 전부 알파벳, 길이 8 → "사용 가능한 비밀번호입니다."
#
# 입력: abc123
# 숫자 포함 → "사용 불가능한 비밀번호입니다."
#
# 입력: abc
# 전부 알파벳이나 길이 3 < 8 → "사용 불가능한 비밀번호입니다."'''

# %%
# 필수예제 8번을 아래 코드에 작성하세요.
password = input("문자를 입력하세요:")

if password.isalpha() and len(password) >= 8:
    print("사용 가능한 비밀번호입니다.")
else: print("사용 불가능한 비밀번호입니다.")
# Out:
# 사용 불가능한 비밀번호입니다.
