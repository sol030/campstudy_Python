# %% [markdown]
# # 🧩 연습문제 03: 불변(immutable) (1~8문제)
#
# 문자열은 한 번 생성되면 그 내용을 직접 수정할 수 없는 **불변(immutable)** 객체입니다. 이 파트에서는 슬라이싱이나 메서드를 활용해 새로운 문자열을 만드는 연습을 합니다.

# %% [markdown]
# ### 문제 1) 슬라이싱으로 첫 글자 대문자 만들기
#
# **문제 설명**
# `word = "python"`에서 슬라이싱과 대문자 변환 기능을 조합하여 첫 글자만 대문자인 `Python`을 만들어 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# Python
# ```
#
# **힌트**
# - 첫 번째 글자만 따로 떼어 대문자로 바꾸고, 나머지 글자들을 슬라이싱으로 떼어내어 서로 더해 보세요.

# %%
# 불변 문제 1
word = "python"

# %% [markdown]
# ### 문제 2) replace로 문자 교체하기
#
# **문제 설명**
# `"hello"`에서 `l`을 모두 대문자 `L`로 바꿔서 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# heLLo
# ```
#
# **힌트**
# - 문자열 내부의 특정 문자를 다른 문자로 일괄 변경해주는 문자열 전용 기능을 사용하세요.

# %%
# 불변 문제 2
text = "hello"

# %% [markdown]
# ### 문제 3) 문자열 이어 붙이기
#
# **문제 설명**
# 문자열 `msg = "good"`에 감탄사 `"!"`를 붙여서 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# good!
# ```
#
# **힌트**
# - 두 개의 문자열 데이터를 하나로 합칠 때 사용하는 산술 연산자를 활용하세요.

# %%
# 불변 문제 3
msg = "good"

# %% [markdown]
# ### 문제 4) 공백 제거와 소문자 변환
#
# **문제 설명**
# `"  ABC  "` 문자열의 양쪽 공백을 제거하고, 모든 글자를 소문자로 바꿔서 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# abc
# ```
#
# **힌트**
# - 문자열 양 끝의 불필요한 빈칸을 지워주는 기능과 대문자를 소문자로 변환하는 기능을 연달아 사용해 보세요.

# %%
# 불변 문제 4
text = "  ABC  "

# %% [markdown]
# ### 문제 5) (헷갈림) replace 실행 후 원본 확인
#
# **문제 설명**
# `text = "apple"`일 때 `text.replace("a", "b")`를 실행한 직후, 다시 `text`를 출력하면 왜 여전히 `"apple"`인지 이유를 설명하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# (설명 텍스트)
#
# **힌트**
# - 문자열은 '불변'이라는 특징 때문에 메서드를 실행한다고 해서 원본 자체가 바뀌지 않는다는 점을 생각해보세요.

# %%
# 불변 문제 5
# 이유: 문자열은

# %% [markdown]
# ### 문제 6) 문자열 인덱싱 기초
#
# **문제 설명**
# `s = "abc"`일 때 `s[1]`은 어떤 문자를 가리키는지 출력해 보세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# b
# ```
#
# **힌트**
# - 프로그래밍에서 순서는 1이 아닌 0부터 시작한다는 점을 유의하여 두 번째 글자를 찾아보세요.

# %%
# 불변 문제 6
s = "abc"

# %% [markdown]
# ### 문제 7) (헷갈림) 문자열 직접 수정 시 에러 확인
#
# **문제 설명**
# 문자열을 수정하려고 `s[0] = "X"`를 시도하면 왜 에러가 나는지 한 줄로 설명해 보세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# (설명 텍스트)
#
# **힌트**
# - 문자열 데이터의 일부분만 골라내서 다른 값으로 덮어쓰는 행위가 허용되는지 생각해 보세요.

# %%
# 불변 문제 7
# 설명:

# %% [markdown]
# ### 문제 8) (도전) 첫 글자만 특정 문자로 바꾸기
#
# **문제 설명**
# `"banana"`에서 모든 `b`가 아니라, 오직 첫 글자인 `b`만 대문자 `B`로 바꿔서 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# Banana
# ```
#
# **힌트**
# - 전체 문자를 대상으로 바꾸는 기능 대신, 위치를 지정하여 첫 글자만 따로 처리하고 나머지는 붙이는 방식을 고민해 보세요.

# %%
# 불변 문제 8
fruit = "banana"

# %% [markdown]
# # 🧩 연습문제 03: 인덱싱/슬라이싱 (1~10문제)
#
# 문자열의 특정 위치에 접근하는 **인덱싱**과 범위를 지정해 부분 문자열을 추출하는 **슬라이싱** 기법을 연습합니다.

# %% [markdown]
# ### 문제 1) 첫 글자와 마지막 글자 추출
#
# **문제 설명**
# `s = "Python"`에서 인덱싱 []을 사용하여 첫 글자와 마지막 글자를 각각 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# P n
# ```
#
# **힌트**
# - 첫 번째 글자는 인덱스 0, 마지막 글자는 -1을 사용합니다.

# %%
# 슬라이싱 문제 1
s = "Python"

# %% [markdown]
# ### 문제 2) 중간 부분 문자열 추출
#
# **문제 설명**
# `s = "abcdef"`에서 슬라이싱을 사용하여 `"bcd"`만 추출해 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# bcd
# ```

# %%
# 슬라이싱 문제 2
s = "abcdef"

# %% [markdown]
# ### 문제 3) 끝에서부터 추출하기
#
# **문제 설명**
# `s = "abcdef"`에서 뒤에서 3글자(`"def"`)를 추출하여 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# def
# ```
#
# **힌트**
# - 음수 인덱스를 사용하세요.

# %%
# 슬라이싱 문제 3
s = "abcdef"

# %% [markdown]
# ### 문제 4) 간격 지정 슬라이싱 (홀수)
#
# **문제 설명**
# `s = "0123456789"`에서 step을 사용하여 `13579`만 추출하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# 13579
# ```
#
# **힌트**
# - [시작:끝:간격] 형식을 사용합니다.

# %%
# 슬라이싱 문제 4
s = "0123456789"

# %% [markdown]
# ### 문제 5) 간격 지정 슬라이싱 (짝수)
#
# **문제 설명**
# `s = "0123456789"`에서 `02468`만 추출하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# 02468
# ```
#
# **힌트**
# - 0번 인덱스부터 시작하세요.

# %%
# 슬라이싱 문제 5
s = "0123456789"

# %% [markdown]
# ### 문제 7) 빈 슬라이싱 확인
#
# **문제 설명**
# `s[0:0]`의 결과를 확인하고 이유를 설명하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# (빈 문자열)
#
# **힌트**
# - 시작과 끝 인덱스가 같으면 범위가 없습니다.

# %%
# 슬라이싱 문제 7
s = "Python"
print(f"'{s[0:0]}'")
# 설명: 시작과 끝 인덱스가 같으면 빈 문자열이 반환됩니다.

# %% [markdown]
# ### 문제 8) 인덱싱과 슬라이싱의 차이
#
# **문제 설명**
# 문자열 "Python"의 `s[-1]`과 `s[-1:]`의 차이를 코드로 확인하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# (결과 및 설명)
#
# **힌트**
# - 반환 타입에 주목하세요.

# %%
# 슬라이싱 문제 8
s = "Python"

# %% [markdown]
# ### 문제 9) 특정 단어 추출하기
#
# **문제 설명**
# `s = "Hello, World!"`에서 `"World"`만 추출하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# World
# ```
#
# **힌트**
# - 시작과 끝 인덱스를 정확히 세어 보세요.

# %%
# 슬라이싱 문제 9
s = "Hello, World!"

# %% [markdown]
# ### 문제 10) 이메일 도메인 추출 (도전)
#
# **문제 설명**
# `email = "abc@gmail.com"`에서 `"gmail"`만 추출하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```
# gmail
# ```
#
# **힌트**
# - @와 . 사이 범위를 슬라이싱합니다.

# %%
# 슬라이싱 문제 10
email = "abc@gmail.com"
print(email[4:9])

# %% [markdown]
# # 🧩 연습문제 03: 전처리 메서드 & find/index (1~10문제)
#
# 문자열 전처리에 필수적인 공백 제거, 문자열 분리 및 결합, 그리고 특정 문자의 위치를 찾는 다양한 메서드들을 연습합니다.

# %% [markdown]
# ### 문제 1) 공백 제거와 소문자 변환
#
# **문제 설명**
# `"   Hello   "` 문자열에서 양쪽 공백을 제거한 뒤, 모두 소문자로 바꾼 `"hello"`를 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```text
# hello
# ```
#
# **힌트**
# * 문자열 양쪽의 빈 칸을 깎아내는 기능과 대문자를 소문자로 바꾸는 기능을 함께 사용해 보세요.

# %%
# 메서드/find/index 문제 1
text = "   Hello   "

# %% [markdown]
# ### 문제 2) 문자열 분리 후 다시 합치기
#
# **문제 설명**
# `"A,B,C"` 문자열을 쉼표(`,`) 기준으로 나눈 뒤, 다시 하이픈(`-`)으로 연결하여 `"A-B-C"`를 만드세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```text
# A-B-C
# ```
#
# **힌트**
# * 구분자를 기준으로 문자열을 리스트로 쪼개는 기능과, 리스트의 요소들을 특정 문자로 이어 붙이는 기능을 순서대로 활용하세요.

# %%
# 메서드/find/index 문제 2
text = "A,B,C"
split_text = text.split()
result = "".join()

# %% [markdown]
# ### 문제 3) 특정 문자열 등장 횟수 세기
#
# **문제 설명**
# `"banana"` 문자열에서 `"na"`라는 단어가 몇 번 포함되어 있는지 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```text
# 2
# ```
#
# **힌트**
# * 문자열 내에서 특정 문자나 단어의 개수를 세어주는 기능을 사용하세요.

# %%
# 메서드/find/index 문제 3
text = "banana"
print(text.count())

# %% [markdown]
# ### 문제 7) 문자열 일괄 교체하기
#
# **문제 설명**
# `"ha ha ha"` 문자열에서 `"ha"`를 모두 `"ho"`로 바꿔 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```text
# ho ho ho
# ```
#
# **힌트**
# * 문자열 전체에서 특정 내용을 바꾸는 기능을 사용하세요.

# %%
# 메서드/find/index 문제 7
text = "ha ha ha"
print(text.replace(,))

# %% [markdown]
# ### 문제 9) 콜론 뒤의 값 추출 및 정제
#
# **문제 설명**
# `"name: 적토마"` 문자열에서 콜론(`:`) 뒤의 값만 추출해 공백을 제거하여 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```text
# 적토마
# ```
#
# **힌트**
# * 콜론의 위치를 찾은 뒤 슬라이싱과 strip()을 사용하세요.

# %%
# 메서드/find/index 문제 9
data = "name: 적토마"
idx = data.find()
name = data[].strip()
print(name)

# %% [markdown]
# ### 문제 10) 날짜 문자열 분리하여 저장하기
#
# **문제 설명**
# `"2026/01/04"` 문자열을 `/` 기준으로 나누어 연, 월, 일을 각각 변수에 담아 출력하세요.
#
# **입력 예시**
# (없음)
#
# **목표 출력**
# ```text
# 연도: 2026, 월: 01, 일: 04
# ```
#
# **힌트**
# * split()과 다중 할당을 활용하세요.

# %%
# 메서드/find/index 문제 10
date_str = "2026/01/04"
year, month, day = date_str.split()
print(f"연도: {year}, 월: {month}, 일: {day}")
