# %%
tree = "소나무"
print(f"안녕하세요 {tree}예요.")
# Out:
# 안녕하세요 소나무예요.

# %%
#편집모드에서 알트엔터라니 너무 귀찮아서 마우스를 써버리고 싶어진다...
#대신 막 코드 위치 바꿀 때 편한 게 참 좋다 가독성도 좋고 코드 완성 나오는 것도 레전드편함

# %%
#에 숙제있다 그럼 이건 금요일에 하죠 ㅎㅎ

# %%
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 데이터 저장하기

data.to_csv("tips_data.csv")    #데이터 저장

# %%
df = pd.read_csv("tips_data.csv")
df
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
data.to_csv("tips_data.csv", index=False)    #인덱스 지정해서 저장하는 방법

#또는
df = pd.read_csv("tips_data.csv", index_col=0)  #불러올 때 지정해주는 방법도 있음
df
# Out:
#              tip     sex smoker   day    time  size
# total_bill
# 16.99       1.01  Female     No   Sun  Dinner     2
# 10.34       1.66    Male     No   Sun  Dinner     3
# 21.01       3.50    Male     No   Sun  Dinner     3
# 23.68       3.31    Male     No   Sun  Dinner     2
# 24.59       3.61  Female     No   Sun  Dinner     4
# ...          ...     ...    ...   ...     ...   ...
# 29.03       5.92    Male     No   Sat  Dinner     3
# 27.18       2.00  Female    Yes   Sat  Dinner     2
# 22.67       2.00    Male    Yes   Sat  Dinner     2
# 17.82       1.75    Male     No   Sat  Dinner     2
# 18.78       3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
#엑셀 파일로 저장하기
import os
os.makedirs("temp", exist_ok=True)

df.to_excel("temp/tips_data.xlsx", index=False)

# %%
#인덱스
df = pd.DataFrame({     #데이터프레임. A, B 각 컬럼에 딕셔너리 형태로 집어넣기
    'A' : [1,2,3],
    'B' : ['a', 'b', 'c']
}, index=['idxl', 'idx2', 'idx3'])    #인덱스는 0으로 시작하는 게 디폴트지만 별도로 이름 지정해줄 수 있음
df
# Out:
#       A  B
# idxl  1  a
# idx2  2  b
# idx3  3  c

# %%
df.loc['idx2']
# Out:
# A    2
# B    b
# Name: idx2, dtype: object

# %%
df.sort_index()     #인덱스 정렬
# Out:
#       A  B
# idx2  2  b
# idx3  3  c
# idxl  1  a

# %%
df.set_index('A')   #'A라는 인덱스를 쓰겠다' 메서드
# Out:
#    B
# A
# 1  a
# 2  b
# 3  c

# %%
df.index	#인덱스가 어떻게 이루어져 있고, 타입은 무엇인지 확인

df.index = ['1', '2', '3']      #인덱스를 추가할 수도 있음
df
# Out:
#    A  B
# 1  1  a
# 2  2  b
# 3  3  c

# %%
df.reset_index()
# Out:
#   index  A  B
# 0     1  1  a
# 1     2  2  b
# 2     3  3  c

# %%
##컬럼
#데이터프레임 생성

import pandas as pd

data = {
    '이름': ['Alice', 'Bob', 'Charlie'],
    '나이': [25, 30, 35],
    '성별': ['여', '남', '남']
}

df = pd.DataFrame(data)

# 각 컬럼 출력
print(df['이름'])
print(df['나이'])
print(df['성별'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: 이름, dtype: object
# 0    25
# 1    30
# 2    35
# Name: 나이, dtype: int64
# 0    여
# 1    남
# 2    남
# Name: 성별, dtype: object

# %%
df['이름']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: 이름, dtype: object

# %%
#컬럼명 변경
df.columns = ['name', 'age', 'gender']
df
# Out:
#       name  age gender
# 0    Alice   25      여
# 1      Bob   30      남
# 2  Charlie   35      남

# %%
#컬럼명 변경2
df.rename(columns={'name': '이름'})
# Out:
#         이름  age gender
# 0    Alice   25      여
# 1      Bob   30      남
# 2  Charlie   35      남

# %%
#컬럼 추가
df['스포츠'] = '축구'
df
# Out:
#       name  age gender 스포츠
# 0    Alice   25      여  축구
# 1      Bob   30      남  축구
# 2  Charlie   35      남  축구

# %%
##데이터 확인
#head()
df.head() # head()은 기본 5개 행에 대한 데이터를 보여줌
df.head(3) # ()안에 숫자만큼 데이터를 보여줌
# Out:
#       name  age gender 스포츠
# 0    Alice   25      여  축구
# 1      Bob   30      남  축구
# 2  Charlie   35      남  축구

# %%
#Info()
df.info() 
# null 값을 확인할때도 활용
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   gender  3 non-null      object
#  3   스포츠     3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 228.0+ bytes

# %%
#describe() 
df.describe()
# 숫자값에 대해서만 기초통계량 확인이 가능
# Out:
#         age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
###결측치 확인
# 결측치 확인 : isnull()
df.isnull().sum() #결측치가 몇개있는지도 알 수 있음
# Out:
# name      0
# age       0
# gender    0
# 스포츠       0
# dtype: int64

# %%
# 결측치 제거 : dropna()
df.dropna()
# Out:
#       name  age gender 스포츠
# 0    Alice   25      여  축구
# 1      Bob   30      남  축구
# 2  Charlie   35      남  축구

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   gender  3 non-null      object
#  3   스포츠     3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 228.0+ bytes

# %%
#데이터 타입 확인
df = pd.read_csv("tips_data.csv")       #아까썼던거가져오기
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#데이터 타입 확인
df['total_bill'].dtype
# Out:
# dtype('float64')

# %%
##데이터 타입 변경

df['total_bill'] = df['total_bill'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    object
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 13.5+ KB

# %%
df['total_bill'] = df['total_bill'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
###
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
}
df = pd.DataFrame(data)

# %%
##OR
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
# iloc을 사용하여 특정 행과 열 선택
selected_data = df.iloc[1:4, 0:2]  # 인덱스 1부터 3까지의 행과 0부터 1까지의 열 선택
print(selected_data)
# Out:
#    A   B
# 1  2  20
# 2  3  30
# 3  4  40

# %%
df.iloc[0,2]
# Out:
# np.int64(100)

# %%
df.iloc[0:2]
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200

# %%
df.iloc[0:4:2]
# Out:
#    A   B    C
# 0  1  10  100
# 2  3  30  300

# %%
df.iloc[0::2]
# Out:
#    A   B    C
# 0  1  10  100
# 2  3  30  300
# 4  5  50  500

# %%
df.iloc[0, 0:2]
# Out:
# A     1
# B    10
# Name: 0, dtype: int64

# %%
###.loc
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
}, index=['a', 'b', 'c', 'd', 'e'])
df
# Out:
#    A   B    C
# a  1  10  100
# b  2  20  200
# c  3  30  300
# d  4  40  400
# e  5  50  500

# %%
df.iloc[:]  #전체 데이터 부르기
# Out:
#    A   B    C
# a  1  10  100
# b  2  20  200
# c  3  30  300
# d  4  40  400
# e  5  50  500

# %%
df.iloc[:, 0]     #첫번째 컬럼만 보겠다
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: A, dtype: int64

# %%
df.loc['b':, 'A']
# Out:
# b    2
# c    3
# d    4
# e    5
# Name: A, dtype: int64

# %%
df.loc['b':'d', 'A':'C']
# Out:
#    A   B    C
# b  2  20  200
# c  3  30  300
# d  4  40  400

# %%
#slicing & selection

df.loc[:, 'A']   #A라는 컬럼의 모든 값을 가져옴
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: A, dtype: int64

# %%
df[['A', 'B']]  #리스트 형태로 묶어줘야 함
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
# d  4  40
# e  5  50

# %%
df.loc[:, ['A', 'C']]
# Out:
#    A    C
# a  1  100
# b  2  200
# c  3  300
# d  4  400
# e  5  500

# %%
df.loc['a': 'b', 'B':'C']
# Out:
#     B    C
# a  10  100
# b  20  200

# %%
###Boolean Indexing / 특정 조건을 만족하는 데이터를 선택

df = pd.read_csv("temp/tips_data.csv")  #아까 썼던 데이터 가져오기
df

##오오 Ctrl + / 주석 아주 편하군...
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df[df['sex']=='Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
#여러 조건
df[(df['sex']=='Male') & (df['smoker']=='Yes')]
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4
# 58        11.24   1.76  Male    Yes   Sat  Dinner     2
# 60        20.29   3.21  Male    Yes   Sat  Dinner     2
# 61        13.81   2.00  Male    Yes   Sat  Dinner     2
# 62        11.02   1.98  Male    Yes   Sat  Dinner     2
# 63        18.29   3.76  Male    Yes   Sat  Dinner     4
# 69        15.01   2.09  Male    Yes   Sat  Dinner     2
# 76        17.92   3.08  Male    Yes   Sat  Dinner     2
# 80        19.44   3.00  Male    Yes  Thur   Lunch     2
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2
# 90        28.97   3.00  Male    Yes   Fri  Dinner     2
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4
# 96        27.28   4.00  Male    Yes   Fri  Dinner     2
# 97        12.03   1.50  Male    Yes   Fri  Dinner     2
# 98        21.01   3.00  Male    Yes   Fri  Dinner     2
# 105       15.36   1.64  Male    Yes   Sat  Dinner     2
# ...

# %%
#여러 조건 (OR)
df[(df['sex']=='Male') | (df['smoker']=='Yes')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [190 rows x 7 columns]

# %%
#여러 조건 (loc)
df.loc[df['size']>3, :]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 33        20.69  2.45  Female     No   Sat  Dinner     4
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 54        25.56  4.34    Male     No   Sun  Dinner     4
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# ...

# %%
#isin()을 활용한 필터링:
df[df['sex'].isin(['Male', 'Female'])]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
###실습

condition = df['tip'] < 2
condition
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
df[condition]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 53         9.94  1.56    Male     No   Sun  Dinner     2
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 70        12.02  1.97    Male     No   Sat  Dinner     2
# 75        10.51  1.25    Male     No   Sat  Dinner     2
# ...

# %%
cond1 = df['size'] >= 9
cond2 = df['tip'] < 2

df[cond1 | cond2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 53         9.94  1.56    Male     No   Sun  Dinner     2
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 70        12.02  1.97    Male     No   Sat  Dinner     2
# 75        10.51  1.25    Male     No   Sat  Dinner     2
# ...

# %%
cond = (df['sex'] == 'Male') \
    & (df['tip'] > 3) \
    & (df['smoker'] == 'Yes') \
    & (df['total_bill'] < 20) \
    & (df['size'] == 4)
df[cond]
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 63       18.29  3.76  Male    Yes  Sat  Dinner     4

# %%
###데이터 추가하기
df['created_at'] = '2024-01-01'
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  created_at
# 0         16.99  1.01  Female     No   Sun  Dinner     2  2024-01-01
# 1         10.34  1.66    Male     No   Sun  Dinner     3  2024-01-01
# 2         21.01  3.50    Male     No   Sun  Dinner     3  2024-01-01
# 3         23.68  3.31    Male     No   Sun  Dinner     2  2024-01-01
# 4         24.59  3.61  Female     No   Sun  Dinner     4  2024-01-01
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  2024-01-01
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  2024-01-01
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  2024-01-01
# 242       17.82  1.75    Male     No   Sat  Dinner     2  2024-01-01
# 243       18.78  3.00  Female     No  Thur  Dinner     2  2024-01-01
#
# [244 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
#  7   created_at  244 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 15.4+ KB

# %%
##지금 string이라서
pd.to_datetime(df['created_at'])
# Out:
# 0     2024-01-01
# 1     2024-01-01
# 2     2024-01-01
# 3     2024-01-01
# 4     2024-01-01
#          ...
# 239   2024-01-01
# 240   2024-01-01
# 241   2024-01-01
# 242   2024-01-01
# 243   2024-01-01
# Name: created_at, Length: 244, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
#  7   created_at  244 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 15.4+ KB

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
#  7   created_at  244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 15.4+ KB

# %%
df['revenue'] = df['total_bill'] + df['tip']
df
# Out:
#      total_bill   tip     sex smoker   day    time  size created_at  revenue
# 0         16.99  1.01  Female     No   Sun  Dinner     2 2024-01-01    18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3 2024-01-01    12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3 2024-01-01    24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2 2024-01-01    26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4 2024-01-01    28.20
# ..          ...   ...     ...    ...   ...     ...   ...        ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3 2024-01-01    34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2 2024-01-01    29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2 2024-01-01    24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2 2024-01-01    19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2 2024-01-01    21.78
#
# [244 rows x 9 columns]

# %%
df['tip'] / df['revenue'] * 100    #저기 레벨링된 컬럼에서 tip에 대한 퍼센트만 보고 싶다
df
# Out:
#      total_bill   tip     sex smoker   day    time  size created_at  revenue
# 0         16.99  1.01  Female     No   Sun  Dinner     2 2024-01-01    18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3 2024-01-01    12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3 2024-01-01    24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2 2024-01-01    26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4 2024-01-01    28.20
# ..          ...   ...     ...    ...   ...     ...   ...        ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3 2024-01-01    34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2 2024-01-01    29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2 2024-01-01    24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2 2024-01-01    19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2 2024-01-01    21.78
#
# [244 rows x 9 columns]

# %%
###데이터 병합
import pandas as pd

# 두 개의 데이터프레임 생성
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 'B': ['B0', 'B1', 'B2']})
df2 = pd.DataFrame({'A': ['A3', 'A4', 'A5'], 'B': ['B3', 'B4', 'B5']})

# %%
### concat()
# 위아래로 데이터프레임 연결
result_vertical = pd.concat([df1, df2], axis=0)

# 좌우로 데이터프레임 연결
result_horizontal = pd.concat([df1, df2], axis=1)

print("위아래 연결 결과:\n", result_vertical)
print("\n좌우 연결 결과:\n", result_horizontal)
# Out:
# 위아래 연결 결과:
#      A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5
#
# 좌우 연결 결과:
#      A   B   A   B
# 0  A0  B0  A3  B3
# 1  A1  B1  A4  B4
# 2  A2  B2  A5  B5

# %%
### merge()
# 두 개의 데이터프레임 생성
left_df = pd.DataFrame({'key': ['A', 'B', 'C', 'D'], 'value': [1, 2, 3, 4]})
right_df = pd.DataFrame({'key': ['B', 'D', 'E', 'F'], 'value': [5, 6, 7, 8]})

# 'key' 열을 기준으로 두 데이터프레임 병합
merged_df = pd.merge(left_df, right_df, on='key', how='inner')

print(merged_df)


###음...? JOIN이잖아?..
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %%
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
    'Value': [1, 2, 3, 4, 5, 6]
}
df = pd.DataFrame(data)

# %%
# 'Category' 열을 기준으로 그룹화하여 'Value'의 연산 수행
grouped = df.groupby('Category').mean()	#평균값 산출

grouped_sum = df.groupby('Category').sum()	#합계
grouped_count = df.groupby('Category').count()	#NULL이 아닌 값(행수) 산출
grouped_max = df.groupby('Category').max()	#최댓값
grouped_min = df.groupby('Category').min()	#최솟값
grouped_fir = df.groupby('Category').first()

# 수치형 데이터의 경우에 연산이 가능
df
grouped
grouped_sum
grouped_count
grouped_max
grouped_min
grouped_fir
# Out:
#           Value
# Category
# A             1
# B             2

# %%
df = pd.read_csv("temp/tips_data.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df[['day', 'total_bill', 'tip', 'size']].groupby('day').mean()
# Out:
#       total_bill       tip      size
# day
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105
# Thur   17.682742  2.771452  2.451613

# %%
df[['sex', 'day', 'total_bill', 'tip', 'size']].groupby(['day', 'sex']).agg({'total_bill': 'max', 'tip': 'mean', 'size': 'sum'})
# Out:
#              total_bill       tip  size
# day  sex
# Fri  Female       22.75  2.781111    19
#      Male         40.17  2.693000    21
# Sat  Female       44.30  2.801786    63
#      Male         50.81  3.083898   156
# Sun  Female       35.26  3.367222    53
#      Male         48.17  3.220345   163
# Thur Female       43.11  2.575625    79
#      Male         41.19  2.980333    73

# %%
##복수의 열을 기준으로 Group by 함수 사용하기

# 샘플 데이터프레임 생성
data = {
    'Category': ['A', 'A', 'B', 'B', 'A', 'B'],
    'SubCategory': ['X', 'Y', 'X', 'Y', 'X', 'Y'],
    'Value': [1, 2, 3, 4, 5, 6]
}
df = pd.DataFrame(data)

# 'Category'와 'SubCategory' 열을 기준으로 그룹화하여 'Value'의 합 계산
grouped_multiple = df.groupby(['Category', 'SubCategory']).sum()

print(grouped_multiple)
# Out:
#                       Value
# Category SubCategory
# A        X                6
#          Y                2
# B        X                3
#          Y               10

# %%
##다양한 집계 함수 적용해보기

# 샘플 데이터프레임 생성
data = {
    'Category': ['A', 'A', 'B', 'B', 'A', 'B'],
    'SubCategory': ['X', 'Y', 'X', 'Y', 'X', 'Y'],
    'Value1': [1, 2, 3, 4, 5, 6],
    'Value2': [10, 20, 30, 40, 50, 60]
}
df = pd.DataFrame(data)

# 'Category'와 'SubCategory' 열을 기준으로 그룹화하여 각 그룹별 'Value1'과 'Value2'의 평균, 합 계산
grouped_multiple = df.groupby(['Category', 'SubCategory']).agg({'Value1': ['mean', 'sum'], 'Value2': 'sum'})

print(grouped_multiple)
# Out:
#                      Value1     Value2
#                        mean sum    sum
# Category SubCategory
# A        X              3.0   6     60
#          Y              2.0   2     20
# B        X              3.0   3     30
#          Y              5.0  10    100

# %%
####삐뿟 테이블
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-01'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 20, 30, 40, 50]
}
df = pd.DataFrame(data)
df
# Out:
#          Date Category  Value
# 0  2023-01-01        A     10
# 1  2023-01-01        B     20
# 2  2023-01-02        A     30
# 3  2023-01-02        B     40
# 4  2023-01-01        A     50

# %%
# 피벗 테이블 생성: 날짜를 행 인덱스로, 카테고리를 열 인덱스로, 값은 'Value'의 합으로 집계
pivot = df.pivot_table(index='Date', columns='Category', values='Value', aggfunc='sum')

pivot
# Out:
# Category     A   B
# Date
# 2023-01-01  60  20
# 2023-01-02  30  40

# %%
##여러 열을 기준으로 피벗 테이블 생성하기
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-01'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'SubCategory': ['X', 'Y', 'X', 'Y', 'X'],
    'Value': [10, 20, 30, 40, 50]
}
df = pd.DataFrame(data)

# 피벗 테이블 생성: 'Date'를 행 인덱스로, 'Category'와 'SubCategory'를 열 인덱스로, 값은 'Value'의 합으로 집계
pivot = df.pivot_table(index='Date', columns=['Category', 'SubCategory'], values='Value', aggfunc='sum')

pivot
# Out:
# Category      A   B
# SubCategory   X   Y
# Date
# 2023-01-01   60  20
# 2023-01-02   30  40

# %%
##집계 함수를 다르게 적용하여 피벗 테이블 생성하기
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-01'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value1': [10, 20, 30, 40, 50],
    'Value2': [100, 200, 300, 400, 500]
}
df = pd.DataFrame(data)

# 피벗 테이블 생성: 'Date'를 행 인덱스로, 'Category'를 열 인덱스로, 값은 'Value1'과 'Value2'의 평균과 합으로 집계
pivot = df.pivot_table(index='Date', columns='Category', values=['Value1', 'Value2'], aggfunc={'Value1': 'mean', 'Value2': 'sum'})

pivot
# Out:
#            Value1       Value2
# Category        A     B      A    B
# Date
# 2023-01-01   30.0  20.0    600  200
# 2023-01-02   30.0  40.0    300  400

# %%
##시각화 (맛보기)
import matplotlib.pyplot as plt

import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-01'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value1': [10, 20, 30, 40, 50],
    'Value2': [100, 200, 300, 400, 500]
}
df = pd.DataFrame(data)

# 피벗 테이블 생성: 'Date'를 행 인덱스로, 'Category'를 열 인덱스로, 값은 'Value1'과 'Value2'의 평균으로 집계
pivot = df.pivot_table(index='Date', columns='Category', values=['Value1', 'Value2'], aggfunc='mean')


# 피벗 테이블의 선 그래프 시각화
pivot.plot(kind='line')
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Pivot Table Visualization')
plt.legend(title='Category')
plt.show()

# %%
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 22, 30, 18, 27],
    'Score': [85, 90, 75, 80, 95]
}
df = pd.DataFrame(data)

# 정렬
sorted_by_score = df.sort_values('Score') # 'Score' 열을 기준으로 오름차순 정렬
sorted_by_score = df.sort_values('Score',ascending=False) # 'Score' 열을 기준으로 내림차순 정렬

sorted_by_score
# Out:
#       Name  Age  Score
# 4      Eva   27     95
# 1      Bob   22     90
# 0    Alice   25     85
# 3    David   18     80
# 2  Charlie   30     75

# %%
import pandas as pd

# 샘플 데이터프레임 생성
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 22, 30, 18, 27],
    'Score': [85, 90, 75, 80, 95]
}
df = pd.DataFrame(data)

# 정렬
sorted_by_index = df.sort_index() # 인덱스를 기준으로 오름차순 정렬
sorted_by_index = df.sort_index(ascending=False) # 인덱스를 기준으로 내림차순 정렬
sorted_by_index
# Out:
#       Name  Age  Score
# 4      Eva   27     95
# 3    David   18     80
# 2  Charlie   30     75
# 1      Bob   22     90
# 0    Alice   25     85

# %%
############## 시각화 ###############
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x, y)
plt.xlabel('X-axis')
plt.xlabel('Y-axis')
plt.title("Example")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 샘플 데이터프레임 생성
data = {
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1]
}
df = pd.DataFrame(data)

# 선 그래프 그리기
df.plot(x='A', y='B')
plt.show()

# %%
#"스타일을 찾는 거야? 여기 있잖아." zzz

ax = df.plot(x='A', y='B', color='green', linestyle='--', marker='o')


plt.show()

# %%
#례범 추가하기
#1 label
ax = df.plot(x='A', y='B', color='green', linestyle='--', marker='o', label='Data Series')

#2 legend
ax.legend(['Data Series'])


#1번 또는 2번 방법으로 범례를 추가할 수 있음
plt.show()

# %%
#축, 제목
ax.set_xlabel('X-axis Label')
ax.set_ylabel('Y-axis Label')
ax.set_title('Title of the Plot')


plt.show()

# %%
##텍스트 추가
ax.text(3, 3, 'Some Text', fontsize=12)

plt.show()

# %%
##종합

import matplotlib.pyplot as plt

# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# 그래프 그리기
plt.plot(x, y, color='green', linestyle='--', marker='o', label='Data Series')

# 추가 설정
plt.xlabel('X-axis Label')  #축
plt.ylabel('Y-axis Label')  #축
plt.title('Title of the Plot')  #제목
plt.legend()    #범례
plt.text(3, 8, 'Some Text', fontsize=12)  # 특정 좌표에 텍스트 추가

# 그래프 출력
plt.show()

# %%
#figsize는 그래프의 가로와 세로 크기를 인치 단위로 설정

# Figure 객체 생성 및 사이즈 설정
plt.figure(figsize=(8, 6))  # 가로 8인치, 세로 6인치



# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# 그래프 그리기
plt.plot(x, y)

# 그래프 출력
plt.show()
