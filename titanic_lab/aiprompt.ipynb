# %% [markdown]
# `너는 파이썬 데이터분석 입문 튜터야.
#
# 첨부한 pdf 파일이 오늘 학습한 내용이야.
# 복습을 하고 싶은데 초보자가 복습해야할 주요 주제 10개 이하로 간단하게 제목만 정리해줘.`
#
# `너는 파이썬 데이터분석 입문 튜터야.
# 아래 [주제]를 복습할 수 있는 실습형 문제를 난이도별로 3개(하/중/상) 만들어줘.
#
# 조건:
# 1) 정답(코드/결과) 절대 제공하지 말 것
# 2) 각 문제는 “데이터 + 해야 할 일”이 포함된 실습형일 것
# 3) 각 문제마다 힌트를 2~3개 제공할 것 (풀이 접근 방식 중심)
# 4) Pandas를 사용하고, 결과는 DataFrame/Series 형태로 확인하는 문제로 구성
# 5) 문제는 초보자가 10~15분 안에 풀 수 있는 분량(상은 20분까지 가능)
#
# [주제]
# (여기에 주제를 넣으세요)
#
# [데이터]
# (여기에 데이터 또는 df 구조를 넣으세요)`

# %% [markdown]
# **1) 주제별 “완성형 프롬프트 예시” (바로 사용 가능)**
#
# **(A) 주제: Series vs DataFrame, index/columns**
#
# `너는 파이썬 데이터분석 입문 튜터야.
# 아래 [주제]를 복습할 수 있는 실습형 문제를 난이도별로 3개(하/중/상) 만들어줘.
#
# 조건:
# - 정답(코드/결과) 제공 금지
# - 각 문제마다 힌트 2~3개(접근 방식 중심)
# - Pandas 사용, 출력은 DataFrame/Series 확인
# - 문제는 짧고 명확하게
#
# [주제]
# Series와 DataFrame 차이, index/columns 개념
#
# [데이터]
# df = pd.DataFrame({
#   "menu": ["Americano","Latte","Latte","Mocha"],
#   "price": [4500, 5000, 5000, 5500],
#   "qty": [2, 1, 3, 1]
# })`
#
#
# **(B) 주제: dtype 확인 & 변환(to_numeric / astype / to_datetime)**
#
# `너는 파이썬 데이터분석 입문 튜터야.
# 아래 [주제]를 복습할 수 있는 실습형 문제를 난이도별로 3개(하/중/상) 만들어줘.
#
# 조건:
# 1) 정답(코드/결과) 절대 제공하지 말 것
# 2) 각 문제는 dtype 확인 → 변환까지 포함
# 3) 힌트는 “무엇을 먼저 확인하고, 어떤 함수로 변환할지” 중심으로 2~3개
# 4) errors 옵션(coerce 등)을 활용해야만 풀 수 있는 문제를 최소 1개 포함
#
# [주제]
# dtype 확인 및 형 변환: 문자열→숫자, 문자열→날짜
#
# [데이터]
# df = pd.DataFrame({
#   "date": ["2026-01-01", "2026/01/02", "not_a_date"],
#   "price": ["4,500원", "5000", None],
#   "qty": ["2", 1, None]
# })`
#
#
# **(C) 주제: 결측치(Null/NaN) 탐지/처리(isna, fillna, dropna) + 왜곡 방지**
#
# `너는 파이썬 데이터분석 입문 튜터야.
# 아래 [주제]를 복습할 수 있는 실습형 문제를 난이도별로 3개(하/중/상) 만들어줘.
#
# 조건:
# - 정답(코드/결과) 제공 금지
# - 결측치 탐지(isna/sum) + 처리(fillna/dropna) 모두 포함
# - 각 문제마다 “처리 방식 선택 이유”를 묻는 문장을 1개 포함
# - 힌트는 접근 방식 위주 2~3개
#
# [주제]
# 결측치 탐지 및 처리 전략(삭제 vs 대체), 처리 후 분석값 비교
#
# [데이터]
# df = pd.DataFrame({
#   "menu": ["Americano","Latte","Latte","Mocha","Tea"],
#   "price": [4500, 5000, None, 5500, 4000],
#   "qty": [2, None, 3, 1, 1]
# })`
#
#
# **(D) 주제: 파생 피처(derived feature) 생성 + groupby 집계**
#
# `너는 파이썬 데이터분석 입문 튜터야.
# 아래 [주제]를 복습할 수 있는 실습형 문제를 난이도별로 3개(하/중/상) 만들어줘.
#
# 조건:
# - 정답(코드/결과) 제공 금지
# - 파생 피처(예: sales=price*qty) 만들기 포함
# - groupby 집계가 들어간 문제를 최소 2개 포함
# - 힌트는 “어떤 컬럼을 만들고 → 어떤 기준으로 묶을지” 중심으로 2~3개
#
# [주제]
# 파생 피처 생성 + groupby 집계(메뉴별/날짜별)
#
# [데이터]
# df = pd.DataFrame({
#   "date": ["2026-01-01","2026-01-01","2026-01-02","2026-01-03"],
#   "menu": ["Americano","Latte","Latte","Mocha"],
#   "price": [4500, 5000, 5000, 5500],
#   "qty": [2, 1, 2, 1]
# })`
#
#
# **(E) 주제: 파일 입출력(CSV/Excel/JSON) 저장 옵션(index, encoding, orient)**
#
# `너는 파이썬 데이터분석 입문 튜터야.
# 아래 [주제]를 복습할 수 있는 실습형 문제를 난이도별로 3개(하/중/상) 만들어줘.
#
# 조건:
# - 정답(코드/결과) 제공 금지
# - 저장/불러오기 모두 포함
# - 최소 1문항은 “옵션을 왜 그렇게 설정해야 하는지” 설명을 요구
# - 힌트는 ‘어떤 함수 + 어떤 옵션’을 떠올리게 하는 방식으로 2~3개
#
# [주제]
# CSV/Excel/JSON 입출력과 옵션(index, encoding, orient)
#
# [데이터]
# df = pd.DataFrame({
#   "menu": ["아메리카노","라떼"],
#   "sales": [9000, 5000]
# })`

# %% [markdown]
# **1번 문제 예시**
#
# 하(기초)
#
# 문제 1) “Series로 꺼내기 vs DataFrame으로 꺼내기”
#
# df에서 price 컬럼을
#
# 1. Series 형태로 꺼내서 변수 s_price에 저장하고
# 2. DataFrame 형태로 꺼내서 변수 df_price에 저장하세요.
#
# 그리고 두 객체의 **타입(type)**과 shape를 각각 확인하세요.
#
# 힌트
#
# - 힌트1: df["col"]과 df[["col"]]의 차이를 떠올려보세요.
# - 힌트2: type(객체), 객체.shape로 비교해보세요.
# - 힌트3: 출력은 s_price와 df_price를 각각 한 번씩 출력해보면 형태가 바로 보입니다.
#
# ---
#
# 중(중급)
#
# 문제 2) “index/columns 구조 한 번에 요약하기”
#
# 다음 요구사항을 만족하는 요약 결과를 1개 DataFrame으로 만드세요.
#
# - 결과 DataFrame은 컬럼이 정확히 2개: ["item", "value"]
# - item에는 아래 항목들이 순서대로 들어가야 함
#     1. "index"
#     2. "columns"
#     3. "shape"
# - value에는 각각의 값(인덱스 목록, 컬럼 목록, shape 튜플)이 들어가야 함
#
# 즉, “df의 구조를 한 장짜리 표로 정리”하는 문제입니다.
# 힌트
#
# - 힌트1: df.index, df.columns, df.shape를 먼저 각각 얻어보세요.
# - 힌트2: pd.DataFrame({"item":[...], "value":[...]}) 형태로 만들면 쉽습니다.
# - 힌트3: df.columns와 df.index는 그대로 넣어도 되고, 보기 좋게 list()로 감싸도 됩니다.
#
# ---
#
# 상(심화)
#
# 문제 3) “index를 의미 있는 값으로 바꾸고, 차이를 설명하기”
#
# menu 컬럼을 **인덱스(index)**로 설정한 새로운 DataFrame df2를 만드세요.
#
# 그 다음 아래를 수행하세요.
#
# 1. df와 df2의 index/columns가 어떻게 달라졌는지 확인
# 2. df2에서 "Latte" 행(들)을 선택해서 출력
# 3. "Latte"가 중복 인덱스인 상황에서 생길 수 있는 특징을 1문장으로 정리(코드 말고 설명)
#
# 힌트
#
# - 힌트1: 인덱스 설정은 set_index()를 떠올려보세요(원본 df를 유지하려면 복사/새 변수 사용).
# - 힌트2: 인덱스로 선택할 때는 df2.loc["Latte"]가 힌트입니다.
# - 힌트3: 인덱스가 중복되면, 한 값을 선택했을 때 결과가 Series가 아니라 DataFrame으로 나올 수 있습니다(상황에 따라 다름).
